# %% [markdown]
# # Border the Image
#
# ## Save in the form of CSV

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
im=plt.imread('iron.jpeg')
plt.imshow(im)

# %%
horz=np.zeros((20,229,3))
vert=np.zeros((267,20,3))

# %%
mid=np.hstack([vert,im,vert])
final=np.vstack([horz,mid,horz])

# %%
top.shape
# Out:
# (460, 355, 3)

# %%
plt.imshow(final.astype("uint"))
plt.axis("off")
plt.show()

# %%
final=final.reshape(307*229, 3)

# %%
df=pd.DataFrame(final,columns=["c1","c2","c3"])

# %%
df.to_csv("catOutput.csv",index=False)

# %%
df=pd.read_csv("catOutput.csv")
